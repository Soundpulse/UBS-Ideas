# %% [markdown]
# ### *Code modified from https://www.tensorflow.org/tutorials/structured_data/time_series#single_step_model*
# ### *Modified by Soundpulse :D*
#
# ## TODO:
#
# - Use Grid Search for better hyperparameters
# - transform the predicted data back to the original axis
# - Ensembling with other predicting architectures (Expotential Smoothing, Regression, KNN Regressor etc.)
# - Extra: Dimensionality Reduction on the dataset? 🤔

# %%
import pandas as pd
import requests
import json
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Data Science Accelerator Credentials 
RESOURCE_ENDPOINT = "https://dsa-stg-edp-api.fr-nonprod.aws.thomsonreuters.com/data/historical-pricing/beta1/views/summaries/" 
access_token = 'tUn7ZD2ZsW9jKiFpoS56ua2g3hnLaUEE8A1nE6cQ'

# %%
ric = 'JPY=' # put the RIC of the asset you want to retrieve data

requestData = {
    'interval': 'P1D',
    'start': '2016-11-01',
    'end': '2019-06-30',
    #"fields": 'TRDPRC_1' # Uncomment this line if you wish to specify which fields to be returned, e.g. TRDPRC_1 is an available field for AAPL.O
};

# %%
def get_data_request(url, requestData):
    """
    HTTP GET request to Refinitiv API
    
    There is more information in the returned dict (i.e. json) object from the API, we store the data in a DataFrame.
    
    :param url: str, the url of the API endpoint
    :param requestData: dict, contains user-defined variables
    :return: DataFrame, containing the historical pricing data. 
        Returned field list order and content can vary depending on the exchange / instrument.
        Therefore returned data must be treated using appropriate parsing techniques.
    """
    dResp = requests.get(url, headers = {'X-api-key': access_token}, params = requestData);       

    if dResp.status_code != 200:
        raise ValueError("Unable to get data. Code %s, Message: %s" % (dResp.status_code, dResp.text));
    else:
        print("Data access successful")
        jResp = json.loads(dResp.text);
        data = jResp[0]['data']
        headers = jResp[0]['headers']  
        names = [headers[x]['name'] for x in range(len(headers))]
        df = pd.DataFrame(data, columns=names )
        return df
    
resource_endpoint_ric = RESOURCE_ENDPOINT + ric  
df = get_data_request(resource_endpoint_ric, requestData)
# Out:
# Data access successful

# %%
print(df.shape)
df.head()
# Out:
# (694, 23)
#          DATE     BID     ASK  BID_HIGH_1  BID_LOW_1  OPEN_BID  MID_PRICE  \
# 0  2019-06-28  107.88  107.91      107.93     107.55    107.78    107.895
# 1  2019-06-27  107.78  107.81      108.15     107.63    107.78    107.795
# 2  2019-06-26  107.77  107.80      107.84     107.08    107.18    107.785
# 3  2019-06-25  107.17  107.20      107.40     106.77    107.29    107.185
# 4  2019-06-24  107.28  107.31      107.53     107.23    107.39    107.295
#
#    NUM_BIDS  ASK_LOW_1  ASK_HIGH_1  ...  ASIACL_BID  EUROP_BID  EURHI_BID  \
# 0   91894.0     107.57      107.96  ...      107.64     107.63     107.85
# 1   94057.0     107.66      108.18  ...      108.04     108.05     108.15
# 2   81259.0     107.11      107.87  ...      107.46     107.47     107.75
# 3   98267.0     106.79      107.43  ...      107.03     106.81     107.14
# 4   86297.0     107.26      107.55  ...      107.39     107.42     107.53
#
#    EURLO_BID  EURCL_BID  AMEROP_BID  AMERHI_BID  AMERLO_BID  AMERCL_BID  \
# 0     107.58     107.84      107.66      107.93      107.62      107.88
# 1     107.66     107.72      107.82      107.94      107.66      107.78
# 2     107.35     107.63      107.67      107.84      107.58      107.77
# 3     106.80     106.91      106.97      107.39      106.82      107.17
# 4     107.23     107.35      107.29      107.53      107.23      107.28
#
#    OPEN_ASK
# 0    107.81
# 1    107.81
# 2    107.21
# 3    107.30
# 4    107.40
#
# [5 rows x 23 columns]

# %%
df['DATE'] = pd.to_datetime(df['DATE']).astype('O')
df.set_index('DATE', inplace=True)

df['dBid']= df.BID_HIGH_1 - df.BID_LOW_1
df['AMER_dBid']= df.AMERHI_BID - df.AMERLO_BID
df['ASIA_dBid']= df.ASIAHI_BID - df.ASIALO_BID
df['EUR_dBid']= df.EURHI_BID - df.EURLO_BID

df['OTC'] = df.AMERCL_BID.shift() - df.AMEROP_BID
df['AMER_OTC'] = df.AMERCL_BID.shift() - df.AMEROP_BID
df['ASIA_OTC'] = df.ASIACL_BID.shift() - df.ASIAOP_BID
df['EUR_OTC'] = df.EURCL_BID.shift() - df.EUROP_BID

df['FT'] = df.AMERCL_BID - df.AMEROP_BID
df['AMER_FT'] = df.AMERCL_BID - df.AMEROP_BID
df['ASIA_FT'] = df.ASIACL_BID - df.ASIAOP_BID
df['EUR_FT'] = df.EURCL_BID - df.EUROP_BID

# %%
# Drop Ask
df = df.drop(columns=['ASK','MID_PRICE','OPEN_ASK','ASK_LOW_1','ASK_HIGH_1'])

# L2 Norm
mu = df.mean()
sig = df.std()
df = (df-mu)/sig

df.head()
# Out:
#                  BID  BID_HIGH_1  BID_LOW_1  OPEN_BID  NUM_BIDS  ASIAOP_BID  \
# DATE
# 2019-06-28 -1.354560   -1.471352  -1.303735 -1.388737 -0.707884   -1.388733
# 2019-06-27 -1.396251   -1.380715  -1.270578 -1.388737 -0.618119   -1.388733
# 2019-06-26 -1.400420   -1.508430  -1.498534 -1.638134 -1.149242   -1.638130
# 2019-06-25 -1.650566   -1.689704  -1.627019 -1.592411 -0.443402   -1.592408
# 2019-06-24 -1.604705   -1.636146  -1.436364 -1.550845 -0.940163   -1.550842
#
#             ASIAHI_BID  ASIALO_BID  ASIACL_BID  EUROP_BID  ...  ASIA_dBid  \
# DATE                                                       ...
# 2019-06-28   -1.455779   -1.357381   -1.427498  -1.427070  ...  -0.703278
# 2019-06-27   -1.323379   -1.324542   -1.263411  -1.254421  ...   0.093774
# 2019-06-26   -1.592316   -1.550310   -1.501337  -1.492841  ...  -0.238331
# 2019-06-25   -1.633691   -1.677562   -1.677731  -1.764146  ...   0.459090
# 2019-06-24   -1.600591   -1.476423   -1.530052  -1.513394  ...  -0.902541
#
#             EUR_dBid       OTC  AMER_OTC  ASIA_OTC   EUR_OTC        FT  \
# DATE
# 2019-06-28 -1.054196       NaN       NaN       NaN       NaN  0.552453
# 2019-06-27 -0.332944  0.071864  0.071864 -0.231369 -0.337620 -0.123834
# 2019-06-26 -0.628002  0.147874  0.147874  1.387019  0.345029  0.240321
# 2019-06-25 -0.824707  1.196813  1.196813  0.270332  1.190921  0.500431
# 2019-06-24 -0.955843 -0.201772 -0.201772 -0.587414 -0.782826 -0.045800
#
#              AMER_FT   ASIA_FT    EUR_FT
# DATE
# 2019-06-28  0.552453 -0.437472  0.506419
# 2019-06-27 -0.123834  0.822916 -0.879180
# 2019-06-26  0.240321  0.885935  0.378123
# 2019-06-25  0.500431 -0.815588  0.224167
# 2019-06-24 -0.045800  0.003664 -0.212040
#
# [5 rows x 29 columns]

# %%
dataset = {}

dataset['GENERAL'] = df[['BID_HIGH_1','BID_LOW_1','NUM_BIDS','dBid','OTC','FT','OPEN_BID','BID']].bfill().values

dataset['AMERICA'] = df[['AMERHI_BID','AMERLO_BID','NUM_BIDS','AMER_dBid','AMER_OTC','AMER_FT','AMEROP_BID','AMERCL_BID']].bfill().values

dataset['ASIA'] =  df[['ASIAHI_BID','ASIALO_BID','NUM_BIDS','ASIA_dBid','ASIA_OTC','ASIA_FT','ASIAOP_BID','ASIACL_BID']].bfill().values

dataset['EUROPE'] =  df[['EURHI_BID','EURLO_BID','NUM_BIDS','EUR_dBid','EUR_OTC','EUR_FT','EUROP_BID','EURCL_BID']].bfill().values

# %%
plottable = df[['BID_HIGH_1','BID_LOW_1','NUM_BIDS','dBid','OTC','FT','OPEN_BID','BID']]
# Warning: Performance Heavy!
# plt.figure(figsize=(30,30))
# sns.pairplot(plottable)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(plottable.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=plt.cm.RdBu, linecolor='white', annot=True)

# %%
# Functions

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)



def create_time_steps(length):
  time_steps = []
  for i in range(-length, 0, 1):
    time_steps.append(i)
  return time_steps



def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()



def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
# Hyperparameters (TODO: Grid Search Tuning， Fix Underfitting)
# 60:20:20 Split
TRAIN_SPLIT=int(0.7*df.shape[0])
# For multivariate_data function
past_history = 50
future_target = 5
STEP = 1
# For LSTM Model (Don't change this unless we have more data!)
BATCH_SIZE = 32
BUFFER_SIZE = 4096
# For fitting the model
EPOCHS=100
EVALUATION_INTERVAL=200
VALIDATION_STEPS=20
LSTM1_NODES = 64
LSTM2_NODES = 32
LSTM3_NODES = 16

#Define Variables
x_train_multi = np.zeros(shape=(0,past_history,8))
y_train_multi = np.zeros(shape=(0,future_target,))
x_val_multi = np.zeros(shape=(0,past_history,8))
y_val_multi = np.zeros(shape=(0,future_target,))


#NEED HELP: CONCATENATE REPEATABLE DATASETS
for data in dataset:

    x_train_multi_temp, y_train_multi_temp = multivariate_data(dataset[data], dataset[data][:, 0], 0,
                                                     TRAIN_SPLIT, past_history,
                                                     future_target, STEP)
    
    x_val_multi_temp, y_val_multi_temp = multivariate_data(dataset[data], dataset[data][:, 0],
                                                 TRAIN_SPLIT, None, past_history,
                                                 future_target, STEP)
    
    x_train_multi = np.concatenate((x_train_multi, x_train_multi_temp), axis=0)
    y_train_multi = np.concatenate((y_train_multi, y_train_multi_temp), axis=0)
    x_val_multi = np.concatenate((x_val_multi, x_val_multi_temp), axis=0)
    y_val_multi = np.concatenate((y_val_multi, y_val_multi_temp), axis=0)
    
    
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# Generated Samples
for x, y in train_data_multi.take(3):
  multi_step_plot(x[0], y[0], np.array([0]))
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-29-9813875ce241> in <module>
#      45
#      46 # Generated Samples
# ---> 47 for x, y in train_data_multi.take(3):
#      48   multi_step_plot(x[0], y[0], np.array([0]))
#
# c:\users\total\appdata\local\programs\python\python35\lib\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in __next__(self)
#     620
#     621   def __next__(self):  # For Python 3 compatibility
# --> 622     return self.next()
#     623
#     624   def _next_internal(self):
#
# c:\users\total\appdata\local\programs\python\python35\lib\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in next(self)
#     664     """Returns a nested structure of `Tensor`s containing the next element."""
#     665     try:
# --> 666       return self._next_internal()
#     667     except errors.OutOfRangeError:
#     668       raise StopIteration
#
# c:\users\total\appdata\local\programs\python\python35\lib\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in _next_internal(self)
#     649             self._iterator_resource,
#     650             output_types=self._flat_output_types,
# --> 651             output_shapes=self._flat_output_shapes)
#     652
#     653       try:
#
# c:\users\total\appdata\local\programs\python\python35\lib\site-packages\tensorflow_core\python\ops\gen_dataset_ops.py in iterator_get_next_sync(iterator, output_types, output_shapes, name)
#    2670       else:
#    2671         message = e.message
# -> 2672       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    2673   # Add nodes to the TensorFlow graph.
#    2674   if not isinstance(output_types, (list, tuple)):
#
# ~\AppData\Roaming\Python\Python35\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Cache should only be read after it has been completed. [Op:IteratorGetNextSync]

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(LSTM1_NODES,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.BatchNormalization())
multi_step_model.add(tf.keras.layers.LSTM(LSTM2_NODES, return_sequences=True, activation='relu'))
multi_step_model.add(tf.keras.layers.BatchNormalization())
multi_step_model.add(tf.keras.layers.LSTM(LSTM3_NODES, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse', metrics=['accuracy'])

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=VALIDATION_STEPS, callbacks=[es])
# Out:
# Train for 200 steps, validate for 20 steps
# Epoch 1/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.0361 - accuracy: 0.3192 - val_loss: 3.9058 - val_accuracy: 0.0944
# Epoch 2/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0363 - accuracy: 0.3188 - val_loss: 3.6005 - val_accuracy: 0.0808
# Epoch 3/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.0420 - accuracy: 0.3235 - val_loss: 3.5384 - val_accuracy: 0.0816
# Epoch 4/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0369 - accuracy: 0.3255 - val_loss: 3.4154 - val_accuracy: 0.0731
# Epoch 5/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0345 - accuracy: 0.3321 - val_loss: 3.1200 - val_accuracy: 0.0799
# Epoch 6/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0359 - accuracy: 0.3316 - val_loss: 4.7346 - val_accuracy: 0.0884
# Epoch 7/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0327 - accuracy: 0.3303 - val_loss: 2.8746 - val_accuracy: 0.0952
# Epoch 8/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0310 - accuracy: 0.3380 - val_loss: 2.6529 - val_accuracy: 0.1207
# Epoch 9/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0309 - accuracy: 0.3386 - val_loss: 2.8311 - val_accuracy: 0.1216
# Epoch 10/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0304 - accuracy: 0.3404 - val_loss: 3.0657 - val_accuracy: 0.1352
# Epoch 11/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0287 - accuracy: 0.3432 - val_loss: 3.0763 - val_accuracy: 0.1301
# Epoch 12/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0312 - accuracy: 0.3433 - val_loss: 3.8545 - val_accuracy: 0.0765
# Epoch 13/100
# 200/200 [==============================] - 26s 132ms/step - loss: 0.0273 - accuracy: 0.3446 - val_loss: 3.3326 - val_accuracy: 0.0995
# Epoch 14/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0284 - accuracy: 0.3437 - val_loss: 3.1747 - val_accuracy: 0.1029
# Epoch 15/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0276 - accuracy: 0.3450 - val_loss: 3.3690 - val_accuracy: 0.1054
# Epoch 16/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0298 - accuracy: 0.3355 - val_loss: 3.0320 - val_accuracy: 0.0799
# Epoch 17/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0256 - accuracy: 0.3450 - val_loss: 2.5503 - val_accuracy: 0.1003
# Epoch 18/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0288 - accuracy: 0.3415 - val_loss: 2.1755 - val_accuracy: 0.0978
# Epoch 19/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0299 - accuracy: 0.3394 - val_loss: 2.2353 - val_accuracy: 0.1054
# Epoch 20/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0355 - accuracy: 0.3312 - val_loss: 2.0049 - val_accuracy: 0.1276
# Epoch 21/100
# 200/200 [==============================] - 27s 136ms/step - loss: 0.0275 - accuracy: 0.3419 - val_loss: 2.2216 - val_accuracy: 0.1293
# Epoch 22/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0289 - accuracy: 0.3405 - val_loss: 2.2349 - val_accuracy: 0.1276
# Epoch 23/100
# 200/200 [==============================] - 28s 140ms/step - loss: 0.0256 - accuracy: 0.3515 - val_loss: 2.1320 - val_accuracy: 0.1267
# Epoch 24/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0266 - accuracy: 0.3495 - val_loss: 2.0613 - val_accuracy: 0.1199
# Epoch 25/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0258 - accuracy: 0.3518 - val_loss: 2.0170 - val_accuracy: 0.1301
# Epoch 26/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0257 - accuracy: 0.3498 - val_loss: 1.8785 - val_accuracy: 0.1301
# Epoch 27/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0234 - accuracy: 0.3537 - val_loss: 1.9918 - val_accuracy: 0.1233
# Epoch 28/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0224 - accuracy: 0.3530 - val_loss: 1.9311 - val_accuracy: 0.1301
# Epoch 29/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0240 - accuracy: 0.3530 - val_loss: 1.9612 - val_accuracy: 0.1395
# Epoch 30/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0224 - accuracy: 0.3520 - val_loss: 2.0091 - val_accuracy: 0.1301
# Epoch 31/100
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0248 - accuracy: 0.3644 - val_loss: 1.9934 - val_accuracy: 0.1165
# Epoch 32/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0264 - accuracy: 0.3606 - val_loss: 2.0872 - val_accuracy: 0.1046
# Epoch 33/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0235 - accuracy: 0.3717 - val_loss: 2.0053 - val_accuracy: 0.1012
# Epoch 34/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0216 - accuracy: 0.3721 - val_loss: 2.0274 - val_accuracy: 0.1139
# Epoch 35/100
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0206 - accuracy: 0.3716 - val_loss: 2.0137 - val_accuracy: 0.1046
# Epoch 36/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0209 - accuracy: 0.3700 - val_loss: 2.0843 - val_accuracy: 0.1063
# Epoch 37/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0211 - accuracy: 0.3751 - val_loss: 2.0739 - val_accuracy: 0.0986
# Epoch 38/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0244 - accuracy: 0.3732 - val_loss: 2.1678 - val_accuracy: 0.1122
# Epoch 39/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0219 - accuracy: 0.3772 - val_loss: 2.2625 - val_accuracy: 0.0961
# Epoch 40/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0205 - accuracy: 0.3762 - val_loss: 2.1796 - val_accuracy: 0.0935
# Epoch 41/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0218 - accuracy: 0.3813 - val_loss: 2.1442 - val_accuracy: 0.1071
# Epoch 42/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0207 - accuracy: 0.3868 - val_loss: 2.0814 - val_accuracy: 0.1012
# Epoch 43/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0198 - accuracy: 0.3813 - val_loss: 2.0557 - val_accuracy: 0.0910
# Epoch 44/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0204 - accuracy: 0.3823 - val_loss: 2.0873 - val_accuracy: 0.1046
# Epoch 45/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0181 - accuracy: 0.3930 - val_loss: 2.0843 - val_accuracy: 0.0859
# Epoch 46/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0194 - accuracy: 0.3945 - val_loss: 2.2615 - val_accuracy: 0.1199
# Epoch 47/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0184 - accuracy: 0.3881 - val_loss: 2.2443 - val_accuracy: 0.1114
# Epoch 48/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0188 - accuracy: 0.3992 - val_loss: 2.3250 - val_accuracy: 0.1131
# Epoch 49/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0189 - accuracy: 0.3957 - val_loss: 2.2949 - val_accuracy: 0.1088
# Epoch 50/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0189 - accuracy: 0.3985 - val_loss: 2.3790 - val_accuracy: 0.1190
# Epoch 51/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0196 - accuracy: 0.3909 - val_loss: 2.2568 - val_accuracy: 0.1088
# Epoch 52/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0167 - accuracy: 0.3998 - val_loss: 2.2557 - val_accuracy: 0.1284
# Epoch 53/100
# 200/200 [==============================] - 26s 130ms/step - loss: 0.0169 - accuracy: 0.4008 - val_loss: 2.2843 - val_accuracy: 0.1216
# Epoch 54/100
# 200/200 [==============================] - 42s 208ms/step - loss: 0.0180 - accuracy: 0.3965 - val_loss: 2.3382 - val_accuracy: 0.1250
# Epoch 55/100
# 200/200 [==============================] - 57s 283ms/step - loss: 0.0190 - accuracy: 0.3973 - val_loss: 2.3056 - val_accuracy: 0.1233
# Epoch 56/100
# 200/200 [==============================] - 29s 144ms/step - loss: 0.0170 - accuracy: 0.4024 - val_loss: 2.2254 - val_accuracy: 0.1284
# Epoch 00056: early stopping

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# Predicted Samples
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
