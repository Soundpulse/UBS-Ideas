# %% [markdown]
# ### *Code modified from https://www.tensorflow.org/tutorials/structured_data/time_series#single_step_model*
# ### *Modified by Soundpulse :D*
#
# ## TODO:
#
# - Use Grid Search for better hyperparameters
# - transform the predicted data back to the original axis
# - Ensembling with other predicting architectures (Expotential Smoothing, Regression, KNN Regressor etc.)
# - Extra: Dimensionality Reduction on the dataset? 🤔

# %%
import pandas as pd
import requests
import json
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Data Science Accelerator Credentials 
RESOURCE_ENDPOINT = "https://dsa-stg-edp-api.fr-nonprod.aws.thomsonreuters.com/data/historical-pricing/beta1/views/summaries/" 
access_token = 'tUn7ZD2ZsW9jKiFpoS56ua2g3hnLaUEE8A1nE6cQ'

# %%
ric = 'JPY=' # put the RIC of the asset you want to retrieve data

requestData = {
    'interval': 'P1D',
    'start': '2016-11-01',
    'end': '2019-06-30',
    #"fields": 'TRDPRC_1' # Uncomment this line if you wish to specify which fields to be returned, e.g. TRDPRC_1 is an available field for AAPL.O
};

# %%
def get_data_request(url, requestData):
    """
    HTTP GET request to Refinitiv API
    
    There is more information in the returned dict (i.e. json) object from the API, we store the data in a DataFrame.
    
    :param url: str, the url of the API endpoint
    :param requestData: dict, contains user-defined variables
    :return: DataFrame, containing the historical pricing data. 
        Returned field list order and content can vary depending on the exchange / instrument.
        Therefore returned data must be treated using appropriate parsing techniques.
    """
    dResp = requests.get(url, headers = {'X-api-key': access_token}, params = requestData);       

    if dResp.status_code != 200:
        raise ValueError("Unable to get data. Code %s, Message: %s" % (dResp.status_code, dResp.text));
    else:
        print("Data access successful")
        jResp = json.loads(dResp.text);
        data = jResp[0]['data']
        headers = jResp[0]['headers']  
        names = [headers[x]['name'] for x in range(len(headers))]
        df = pd.DataFrame(data, columns=names )
        return df
    
resource_endpoint_ric = RESOURCE_ENDPOINT + ric  
df = get_data_request(resource_endpoint_ric, requestData)
# Out:
# Data access successful

# %%
print(df.shape)
df.head()
# Out:
# (694, 23)
#          DATE     BID     ASK  BID_HIGH_1  BID_LOW_1  OPEN_BID  MID_PRICE  \
# 0  2019-06-28  107.88  107.91      107.93     107.55    107.78    107.895
# 1  2019-06-27  107.78  107.81      108.15     107.63    107.78    107.795
# 2  2019-06-26  107.77  107.80      107.84     107.08    107.18    107.785
# 3  2019-06-25  107.17  107.20      107.40     106.77    107.29    107.185
# 4  2019-06-24  107.28  107.31      107.53     107.23    107.39    107.295
#
#    NUM_BIDS  ASK_LOW_1  ASK_HIGH_1  ...  ASIACL_BID  EUROP_BID  EURHI_BID  \
# 0   91894.0     107.57      107.96  ...      107.64     107.63     107.85
# 1   94057.0     107.66      108.18  ...      108.04     108.05     108.15
# 2   81259.0     107.11      107.87  ...      107.46     107.47     107.75
# 3   98267.0     106.79      107.43  ...      107.03     106.81     107.14
# 4   86297.0     107.26      107.55  ...      107.39     107.42     107.53
#
#    EURLO_BID  EURCL_BID  AMEROP_BID  AMERHI_BID  AMERLO_BID  AMERCL_BID  \
# 0     107.58     107.84      107.66      107.93      107.62      107.88
# 1     107.66     107.72      107.82      107.94      107.66      107.78
# 2     107.35     107.63      107.67      107.84      107.58      107.77
# 3     106.80     106.91      106.97      107.39      106.82      107.17
# 4     107.23     107.35      107.29      107.53      107.23      107.28
#
#    OPEN_ASK
# 0    107.81
# 1    107.81
# 2    107.21
# 3    107.30
# 4    107.40
#
# [5 rows x 23 columns]

# %%
df['DATE'] = pd.to_datetime(df['DATE']).astype('O')
df.set_index('DATE', inplace=True)

df['dBid']= df.BID_HIGH_1 - df.BID_LOW_1
df['dAsk']= df.ASK_HIGH_1 - df.ASK_LOW_1
df['AMER_dBid']= df.AMERHI_BID - df.AMERLO_BID
df['ASIA_dBid']= df.ASIAHI_BID - df.ASIALO_BID
df['EUR_dBid']= df.EURHI_BID - df.EURLO_BID

df['OTC'] = df.AMERCL_BID.shift() - df.AMEROP_BID
df['AMER_OTC'] = df.AMERCL_BID.shift() - df.AMEROP_BID
df['ASIA_OTC'] = df.ASIACL_BID.shift() - df.ASIAOP_BID
df['EUR_OTC'] = df.EURCL_BID.shift() - df.EUROP_BID

df['AMER_FT'] = df.AMERCL_BID - df.AMEROP_BID
df['ASIA_FT'] = df.ASIACL_BID - df.ASIAOP_BID
df['EUR_FT'] = df.EURCL_BID - df.EUROP_BID

# %%
# 20 Cols
df = df.drop(columns=['AMEROP_BID', 'ASIAOP_BID', 'EUROP_BID', 'BID_HIGH_1', 'BID_LOW_1', 'ASK_HIGH_1', 'ASK_LOW_1'
          ,'AMERHI_BID','AMERLO_BID','ASIAHI_BID','ASIALO_BID','EURHI_BID','EURLO_BID','dAsk'])

# 6 Cols (Independent)
# df = df[['BID','AMER_dBid','AMER_OTC','AMER_FT','NUM_BIDS']]
df = df.bfill()
df.head(10)
# Out:
#                BID     ASK  OPEN_BID  MID_PRICE  NUM_BIDS  ASIACL_BID  \
# DATE
# 2019-06-28  107.88  107.91    107.78    107.895   91894.0      107.64
# 2019-06-27  107.78  107.81    107.78    107.795   94057.0      108.04
# 2019-06-26  107.77  107.80    107.18    107.785   81259.0      107.46
# 2019-06-25  107.17  107.20    107.29    107.185   98267.0      107.03
# 2019-06-24  107.28  107.31    107.39    107.295   86297.0      107.39
# 2019-06-21  107.30  107.33    107.30    107.315  103704.0      107.45
# 2019-06-20  107.29  107.32    108.08    107.305  104670.0      107.66
# 2019-06-19  108.09  108.12    108.44    108.105   84189.0      108.37
# 2019-06-18  108.44  108.47    108.53    108.455   83698.0      108.24
# 2019-06-17  108.55  108.56    108.44    108.555   65604.0      108.56
#
#             EURCL_BID  AMERCL_BID  OPEN_ASK  dBid  AMER_dBid  ASIA_dBid  \
# DATE
# 2019-06-28     107.84      107.88    107.81  0.38       0.31       0.28
# 2019-06-27     107.72      107.78    107.81  0.52       0.28       0.52
# 2019-06-26     107.63      107.77    107.21  0.76       0.26       0.42
# 2019-06-25     106.91      107.17    107.30  0.63       0.57       0.63
# 2019-06-24     107.35      107.28    107.40  0.30       0.30       0.22
# 2019-06-21     107.54      107.30    107.33  0.69       0.44       0.48
# 2019-06-20     107.50      107.29    108.11  0.93       0.59       0.68
# 2019-06-19     108.36      108.09    108.47  0.72       0.60       0.39
# 2019-06-18     108.39      108.44    108.56  0.62       0.62       0.38
# 2019-06-17     108.56      108.55    108.43  0.32       0.22       0.30
#
#             EUR_dBid   OTC  AMER_OTC  ASIA_OTC  EUR_OTC  AMER_FT  ASIA_FT  \
# DATE
# 2019-06-28      0.27  0.06      0.06     -0.14    -0.21     0.22    -0.14
# 2019-06-27      0.49  0.06      0.06     -0.14    -0.21    -0.04     0.26
# 2019-06-26      0.40  0.11      0.11      0.86     0.25     0.10     0.28
# 2019-06-25      0.34  0.80      0.80      0.17     0.82     0.20    -0.26
# 2019-06-24      0.30 -0.12     -0.12     -0.36    -0.51    -0.01     0.00
# 2019-06-21      0.68 -0.27     -0.27      0.09     0.26    -0.25     0.15
# 2019-06-20      0.42 -0.47     -0.47     -0.63    -0.09    -0.48    -0.42
# 2019-06-19      0.27 -1.10     -1.10     -0.78    -0.84    -0.30    -0.07
# 2019-06-18      0.62 -0.20     -0.20     -0.16     0.03     0.15    -0.29
# 2019-06-17      0.21 -0.24     -0.24     -0.20    -0.20    -0.13     0.12
#
#             EUR_FT
# DATE
# 2019-06-28    0.21
# 2019-06-27   -0.33
# 2019-06-26    0.16
# 2019-06-25    0.10
# 2019-06-24   -0.07
# 2019-06-21    0.45
# 2019-06-20   -0.13
# 2019-06-19    0.02
# 2019-06-18    0.06
# 2019-06-17   -0.03

# %%
# Warning: Performance Heavy!
plt.figure(figsize=(30,30))
#sns.pairplot(df)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, 
           square=True, cmap=plt.cm.RdBu, linecolor='white', annot=True)

# %%
# Hyperparameters
# 50:25;25 Split
TRAIN_SPLIT=int(0.5*df.shape[0])

mu = df.mean()
sig = df.std()
dataset = (df-mu)/sig
dataset = dataset.values

# %%
# Functions

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)



def create_time_steps(length):
  time_steps = []
  for i in range(-length, 0, 1):
    time_steps.append(i)
  return time_steps



def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()



def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
# Hyperparameters (TODO: Grid Search Tuning， Fix Underfitting)
# For multivariate_data function
past_history = 80
future_target = 1
STEP = 1
# For LSTM Model (Don't change this unless we have more data!)
BATCH_SIZE = 32
BUFFER_SIZE = 4096
# For fitting the model
EPOCHS= 100
EVALUATION_INTERVAL=200
VALIDATION_STEPS=20
LSTM1_NODES = 32
LSTM2_NODES = 16
LSTM3_NODES = 8

# Grid_Search_Variables = [past_history, BATCH_SIZE， EPOCHS]

x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# Generated Samples
for x, y in train_data_multi.take(3):
  multi_step_plot(x[0], y[0], np.array([0]))
# Out:
# Single window of past history : (80, 20)
#
#  Target temperature to predict : (1,)

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(LSTM1_NODES,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.BatchNormalization())
multi_step_model.add(tf.keras.layers.LSTM(LSTM2_NODES, activation='relu', return_sequences=True))
multi_step_model.add(tf.keras.layers.BatchNormalization())
multi_step_model.add(tf.keras.layers.LSTM(LSTM3_NODES, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(future_target))

multi_step_model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse')

multi_step_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 80, 32)            6784
# _________________________________________________________________
# batch_normalization (BatchNo (None, 80, 32)            128
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 80, 16)            3136
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 80, 16)            64
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 10,921
# Trainable params: 10,825
# Non-trainable params: 96
# _________________________________________________________________

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=VALIDATION_STEPS)
# Out:
# Train for 200 steps, validate for 20 steps
# Epoch 1/100
# 200/200 [==============================] - 44s 218ms/step - loss: 0.3689 - val_loss: 0.9119
# Epoch 2/100
# 200/200 [==============================] - 37s 184ms/step - loss: 0.1339 - val_loss: 0.8956
# Epoch 3/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0989 - val_loss: 2.3502
# Epoch 4/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0832 - val_loss: 2.1800
# Epoch 5/100
# 200/200 [==============================] - 37s 186ms/step - loss: 0.0706 - val_loss: 2.1836
# Epoch 6/100
# 200/200 [==============================] - 37s 186ms/step - loss: 0.0598 - val_loss: 1.6939
# Epoch 7/100
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0541 - val_loss: 1.8352
# Epoch 8/100
# 200/200 [==============================] - 39s 195ms/step - loss: 0.0500 - val_loss: 1.1119
# Epoch 9/100
# 200/200 [==============================] - 40s 198ms/step - loss: 0.0475 - val_loss: 1.6618
# Epoch 10/100
# 200/200 [==============================] - 41s 204ms/step - loss: 0.0414 - val_loss: 1.3136
# Epoch 11/100
# 200/200 [==============================] - 38s 191ms/step - loss: 0.0377 - val_loss: 1.4529
# Epoch 12/100
# 200/200 [==============================] - 38s 192ms/step - loss: 0.0368 - val_loss: 0.7934
# Epoch 13/100
# 200/200 [==============================] - 39s 193ms/step - loss: 0.0341 - val_loss: 1.0721
# Epoch 14/100
# 200/200 [==============================] - 39s 197ms/step - loss: 0.0327 - val_loss: 1.3890
# Epoch 15/100
# 200/200 [==============================] - 24s 118ms/step - loss: 0.0325 - val_loss: 1.1096
# Epoch 16/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.0319 - val_loss: 0.6947
# Epoch 17/100
# 200/200 [==============================] - 38s 189ms/step - loss: 0.0302 - val_loss: 0.7311
# Epoch 18/100
# 200/200 [==============================] - 38s 189ms/step - loss: 0.0298 - val_loss: 0.7513
# Epoch 19/100
# 200/200 [==============================] - 38s 190ms/step - loss: 0.0289 - val_loss: 0.7329
# Epoch 20/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.0296 - val_loss: 0.9161
# Epoch 21/100
# 200/200 [==============================] - 16s 80ms/step - loss: 0.0258 - val_loss: 0.7431
# Epoch 22/100
# 200/200 [==============================] - 16s 79ms/step - loss: 0.0264 - val_loss: 1.1562
# Epoch 23/100
# 200/200 [==============================] - 34s 171ms/step - loss: 0.0274 - val_loss: 0.8206
# Epoch 24/100
# 200/200 [==============================] - 40s 199ms/step - loss: 0.0231 - val_loss: 0.8028
# Epoch 25/100
# 200/200 [==============================] - 36s 182ms/step - loss: 0.0229 - val_loss: 1.0336
# Epoch 26/100
# 200/200 [==============================] - 40s 201ms/step - loss: 0.0243 - val_loss: 0.9211
# Epoch 27/100
# 200/200 [==============================] - 41s 206ms/step - loss: 0.0228 - val_loss: 0.9927
# Epoch 28/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0231 - val_loss: 1.0348
# Epoch 29/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0219 - val_loss: 1.0656
# Epoch 30/100
# 200/200 [==============================] - 29s 144ms/step - loss: 0.0243 - val_loss: 0.8701
# Epoch 31/100
# 200/200 [==============================] - 40s 200ms/step - loss: 0.0215 - val_loss: 1.4098
# Epoch 32/100
# 200/200 [==============================] - 38s 189ms/step - loss: 0.0220 - val_loss: 0.9442
# Epoch 33/100
# 200/200 [==============================] - 41s 205ms/step - loss: 0.0201 - val_loss: 0.7497
# Epoch 34/100
# 200/200 [==============================] - 37s 183ms/step - loss: 0.0215 - val_loss: 1.0866
# Epoch 35/100
# 200/200 [==============================] - 40s 198ms/step - loss: 0.0189 - val_loss: 1.0887
# Epoch 36/100
# 200/200 [==============================] - 40s 202ms/step - loss: 0.0210 - val_loss: 1.0696
# Epoch 37/100
# 200/200 [==============================] - 40s 200ms/step - loss: 0.0219 - val_loss: 0.6354
# Epoch 38/100
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0186 - val_loss: 1.2223
# Epoch 39/100
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0197 - val_loss: 1.0477
# Epoch 40/100
# 200/200 [==============================] - 38s 189ms/step - loss: 0.0188 - val_loss: 1.1109
# Epoch 41/100
# 200/200 [==============================] - 35s 176ms/step - loss: 0.0185 - val_loss: 1.0237
# Epoch 42/100
# 200/200 [==============================] - 29s 146ms/step - loss: 0.0186 - val_loss: 0.9648
# Epoch 43/100
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0175 - val_loss: 1.0328
# Epoch 44/100
# 200/200 [==============================] - 43s 215ms/step - loss: 0.0165 - val_loss: 0.9291
# Epoch 45/100
# 200/200 [==============================] - 32s 160ms/step - loss: 0.0204 - val_loss: 1.1392
# Epoch 46/100
# 200/200 [==============================] - 14s 69ms/step - loss: 0.0177 - val_loss: 1.0647
# Epoch 47/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.0183 - val_loss: 1.2698
# Epoch 48/100
# 200/200 [==============================] - 20s 100ms/step - loss: 0.0189 - val_loss: 1.2070
# Epoch 49/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.0167 - val_loss: 1.2806
# Epoch 50/100
# 200/200 [==============================] - 20s 102ms/step - loss: 0.0160 - val_loss: 1.1705
# Epoch 51/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.0159 - val_loss: 1.2067
# Epoch 52/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.0161 - val_loss: 0.7880
# Epoch 53/100
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0177 - val_loss: 1.1286
# Epoch 54/100
# 200/200 [==============================] - 17s 86ms/step - loss: 0.0163 - val_loss: 1.0444
# Epoch 55/100
# 200/200 [==============================] - 17s 84ms/step - loss: 0.0158 - val_loss: 1.2725
# Epoch 56/100
#  36/200 [====>.........................] - ETA: 13s - loss: 0.0155

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# Predicted Samples
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
